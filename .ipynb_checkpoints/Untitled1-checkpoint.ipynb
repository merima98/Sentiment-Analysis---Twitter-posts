# %%
import time

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import nltk 
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HOME\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import io

# %%
import unicodedata 
import numpy as np

# %%
import re 
import string

# %%
from numpy import linalg 
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
from nltk.tokenize import sent_tokenize, word_tokenize 
from nltk.tokenize import PunktSentenceTokenizer

# %%
from nltk.tokenize import PunktSentenceTokenizer 
from nltk.corpus import webtext

# %%
from nltk.stem.porter import PorterStemmer 
from nltk.stem.wordnet import WordNetLemmatizer

# %%
with open('facebook.txt', encoding ='ISO-8859-2') as f: 
    text = f.read()

# %%
sent_tokenizer = PunktSentenceTokenizer(text) 
sents = sent_tokenizer.tokenize(text)

# %%
print(word_tokenize(text)) 
print(sent_tokenize(text))
# Out:
# ['Steven', 'Janse', 'je', 'kerst', 'engel', 'zit', 'klaar', ',', 'waar', 'ben', 'jij', '?', 'ŘŻŘšŘ§', 'Ů\x84Ů\x8aŘ¨Ř§', 'á\x83\x97á\x83\x91á\x83\x98á\x83\x9aá\x83\x98á\x83Ąá\x83¨á\x83\x98', 'á\x83Žá\x83\x90á\x83', '?', 'Look', 'always', 'good', '.', 'magical', 'Beautiful', 'Mau', 'Pavia', 'Jr.', 'Feliz', 'navidad', 'Te', 'hablan', 'Jorge', 'Alberto', 'Vadillo', 'Ramirez', 'Goegeous', '.', 'O', 'gon', 'the', 'biggest', '&', 'sweetest', 'snowflake', 'on', 'earth', '.', 'á\x83\x97á\x83\x91á\x83\x98á\x83\x9aá\x83\x98á\x83Ąá\x83¨á\x83\x98', 'á\x83Žá\x83\x90á\x83', '?', 'I', 'love', 'that', 'tree', '.', 'I', 'seriously', 'think', 'that', 'right', 'now', '...', 'you', "'re", 'the', 'prettiest', 'female', 'artist', 'in', 'the', 'world', '.', 'What', 'a', 'wonderful', 'style', 'Liana', 'Lord', 'Fantastique', 'Linda', 'Dua', 'lipa', 'Reece', 'Williams', 'Whereâ\x80\x99s', 'your', 'soul', 'girl', '?', '!', 'Merry', 'Christmas', 'â\x9d¤ď¸\x8f', 'si', 'belle', 'so', 'beautiful', 'bellissima', 'Beautiful', 'She', "'s", 'FIREEEE', 'Hasta', 'que', 'al', 'fin', 'te', 'pusiste', 'el', 'conjunto', 'que', 'te', 'compre', 'â\x9d¤ď¸\x8f', 'Beautiful', 'Oyeeee', 'Arin', 'Lowrance', 'Costa', 'she', 'is', 'my', 'Girl', 'â\x9d¤ď¸\x8f', 'A', 'Gg', '1', 'Ů\x82ŘąŮ\x81', 'Livia', 'Dinehart', 'thought', 'this', 'was', 'you', 'Linda', 'Etai', 'Zilberman', '×\x9c×\x90', '×\x99×\x9b×\x95×\x9c', '×˘×\x9d', '×\x94×\x90×', '×\x98×\x99×Š×\x9e×\x99×Ş', '×\x94×\x99×¤×\x94', '×\x94×\x96×\x90×Ş', '×\x9c×\x90', '×˘×\x95×Š×\x94', '×\x9c×\x9a', '×\x9c×\x99×\x99×§', '×\x99×\x9e×\x9b×\x95×˘×¨×Ş', 'Prettyyyyyy', 'Desearia', 'estar', 'contigo', 'I', 'thought', 'u', 'were', 'dixie', 'Maria', 'Antonia', 'Rosa', 'Braga', 'Wah', '!', 'Christmas', 'is', 'coming', 'á\x83', 'á\x83\x90', 'á\x83\x9aá\x83\x90á\x83\x9bá\x83\x90á\x83\x96á\x83\x98', 'á\x83\x9cá\x83\x90á\x83Ťá\x83\x95á\x83\x98á\x83Ą', 'á\x83Žá\x83\x94á\x83\x90', 'â\x9c¨DLJDâ\x9c¨ď¸\x8f', '...', "'", 'I', 'wish', 'you', 'a', 'Merry', 'Christmas', '!', 'I', 'wish', 'you', 'a', 'merry', 'Christmas', '!', 'and', ',', 'a', 'happy', 'New', 'Year', '!', "'Merry", 'Christmas', 'Ms', 'Dua', '!', 'â\x9c¨â\x98\x83ď¸\x8fâ\x80\x8dâ\x9c¨Merry', 'Christmas', 'Dear', 'Jimmy', '!', 'â\x9c¨â\x98\x83ď¸\x8fâ\x80\x8dâ\x9c¨', 'would', 'you', 'kiss', 'me', '?', 'GG', 'Wow', 'Beautiful', 'xxx', 'Um', 'beijo', 'meu', 'amor', '!', '!', '!', '!', '!', '!', '!', 'Hola', 'mi', 'reina', 'Dios', 'te', 'cuide', ',', 'te', 'estamos', 'esperando', 'para', 'la', 'cena', 'navideĂąa', 'mi', 'princesa', 'Ř§Ů\x8aŮ\x88Ř§', 'Ů\x83ŘŻŘ§', 'Ř§ŘŞŘšŘŻŮ\x84Ů\x8a', 'Ů\x88', 'Ů\x86Ř˛Ů\x84Ů\x8a', 'ŘľŮ\x88ŘąŘŠ', 'ŘšŘŻŮ\x84ŘŠ', 'Pray', 'for', 'me', ',', 'my', 'love', '.', 'ŘŞŮ\x8aŘ§Ř¨Ů\x83', 'Ů', 'ŘŞŮ\x84', 'Ů\x86Ů\x82Ř´ŘŠ', 'Ř´ŘąŘ´Ů\x81', 'Ř§Ů\x84ŘłŮ\x81ŘąŘŠ', 'ŘšŮ\x86Ř§', 'I', 'love', 'you', 'dua', 'â\x9d¤', 'Nice', 'Luka', 'Jureta', 'radi', 'li', 'se', 'o', 'stablou', 'na', 'vinkovec', 'corso', '?', 'ZaĹĄto', 'dua', 'nikad', 'ne', 's', 'mi', 'vincovec', 'shopping', 'mall', '?', 'U', 'r', 'beautifuul', 'á\x83Łá\x83Ł', 'á\x83\x97á\x83\x94á\x83\x9c', 'á\x83\x92á\x83\x94á\x83\x9cá\x83\x90á\x83\x97á\x83\x90á\x83\x9aá\x83\x94á\x83\x94', 'â\x9d¤ď¸\x8f', 'se', 'mi', 'amiga', 'por', 'favor', 'Benjamin', 'Trejo', 'â\x9d¤â\x9d¤â\x9d¤â\x9d¤', 'Amo', 'que', 'es', 'tan', 'bella', 'quĂ˘Ě\x81n', 'caĚ\x81i', 'khÄ\x83n', 'traĚ\x89i', 'baĚ\x80n', 'haĚ\x89', ':', "'", '(', 'Wow', 'you', 'are', 'my', 'wonder', 'woman', '.', 'Merry', 'Christmas', 'my', 'love', 'Eso', 'es', 'en', 'la', 'plaza', 'de', 'Araure', 'verdad', 'look', 'contesto', 'top', 'Mi', 'amoor', 'nice', 'Hi', 'Hi', 'Merry', 'christmas', 'xD', 'â\x9c¨â\x9c¨â\x9c¨', 'All', '.', 'Pretty', 'Dope', 'stylo', 'as', 'always', 'Dua', 'this', 'is', 'really', 'elegant', 'and', 'so', 'freaking', 'you', 'amazing', 'love', 'it', 'So', 'hottt', 'â\x9d¤', 'One', 'of', 'my', 'fevaleti', 'gilo', 'Affan', 'Raiyan', 'Siddiqui', 'feshana', 'gorer', 'So', 'beautiful', 'â\x99Ľď¸\x8fâ\x99Ľď¸\x8fâ\x99Ľď¸\x8f', 'Vamos', 'Argentina', 'Ř§Ř\xadŮ\x84Ů\x8a' ...
# ['Steven Janse je kerst engel zit klaar, waar ben jij?', 'ŘŻŘšŘ§ Ů\x84Ů\x8aŘ¨Ř§\ná\x83\x97á\x83\x91á\x83\x98á\x83\x9aá\x83\x98á\x83Ąá\x83¨á\x83\x98 á\x83Žá\x83\x90á\x83\xa0?', 'Look always good.', 'magical\nBeautiful\nMau Pavia Jr. Feliz navidad \nTe hablan Jorge Alberto Vadillo Ramirez\nGoegeous.', 'O gon\nthe biggest & sweetest snowflake on earth .', 'á\x83\x97á\x83\x91á\x83\x98á\x83\x9aá\x83\x98á\x83Ąá\x83¨á\x83\x98 á\x83Žá\x83\x90á\x83\xa0?', 'I love that tree.', "I seriously think that right now... you're the prettiest female artist in the world.", 'What a wonderful style\n\nLiana Lord \nFantastique\nLinda Dua lipa\nReece Williams\nWhereâ\x80\x99s your soul girl?!', "Merry  Christmas â\x9d¤ď¸\x8f\n\nsi belle so beautiful bellissima \n\nBeautiful\nShe's FIREEEE\nHasta que al fin te pusiste el conjunto que te compre â\x9d¤ď¸\x8f\nBeautiful \nOyeeee\nArin Lowrance Costa  she is my Girl â\x9d¤ď¸\x8f\nA\nGg\n1\nŮ\x82ŘąŮ\x81 \nLivia Dinehart thought this was you \nLinda\nEtai Zilberman ×\x9c×\x90 ×\x99×\x9b×\x95×\x9c ×˘×\x9d ×\x94×\x90×\xa0×\x98×\x99×Š×\x9e×\x99×Ş ×\x94×\x99×¤×\x94 ×\x94×\x96×\x90×Ş \n×\x9c×\x90 ×˘×\x95×Š×\x94 ×\x9c×\x9a ×\x9c×\x99×\x99×§ ×\x99×\x9e×\x9b×\x95×˘×¨×Ş\nPrettyyyyyy\nDesearia estar contigo\n\nI thought u were dixie\nMaria Antonia Rosa Braga \nWah!Christmas is coming\n\ná\x83\xa0á\x83\x90 á\x83\x9aá\x83\x90á\x83\x9bá\x83\x90á\x83\x96á\x83\x98 á\x83\x9cá\x83\x90á\x83Ťá\x83\x95á\x83\x98á\x83Ą á\x83Žá\x83\x94á\x83\x90\n\n\n\n\nâ\x9c¨DLJDâ\x9c¨ď¸\x8f ...'I wish you a Merry Christmas !I wish you a merry Christmas !and, a happy New Year !", "'Merry Christmas Ms Dua!", 'â\x9c¨â\x98\x83ď¸\x8fâ\x80\x8dâ\x9c¨Merry Christmas Dear Jimmy !â\x9c¨â\x98\x83ď¸\x8fâ\x80\x8dâ\x9c¨\nwould you kiss me?', 'GG\nWow \nBeautiful xxx\nUm beijo meu amor !!!!!!!', 'Hola mi reina Dios te cuide, te estamos esperando para la cena navideĂąa mi princesa\nŘ§Ů\x8aŮ\x88Ř§ Ů\x83ŘŻŘ§ Ř§ŘŞŘšŘŻŮ\x84Ů\x8a Ů\x88 Ů\x86Ř˛Ů\x84Ů\x8a ŘľŮ\x88ŘąŘŠ ŘšŘŻŮ\x84ŘŠ\nPray for me, my love.', 'ŘŞŮ\x8aŘ§Ř¨Ů\x83 Ů\x85ŘŞŮ\x84 Ů\x86Ů\x82Ř´ŘŠ Ř´ŘąŘ´Ů\x81 Ř§Ů\x84ŘłŮ\x81ŘąŘŠ ŘšŮ\x86Ř§ \nI love you dua â\x9d¤\nNice\nLuka Jureta radi li se o stablou na vinkovec corso?', 'ZaĹĄto dua nikad ne s mi vincovec shopping mall?', "U r beautifuul\n\ná\x83Łá\x83Ł á\x83\x97á\x83\x94á\x83\x9c á\x83\x92á\x83\x94á\x83\x9cá\x83\x90á\x83\x97á\x83\x90á\x83\x9aá\x83\x94á\x83\x94\nâ\x9d¤ď¸\x8f\nse mi amiga por favor\nBenjamin Trejo â\x9d¤â\x9d¤â\x9d¤â\x9d¤\nAmo que es tan bella\nquĂ˘Ě\x81n caĚ\x81i khÄ\x83n traĚ\x89i baĚ\x80n haĚ\x89 :'( \nWow you are my wonder woman.", 'Merry Christmas my love\nEso es en la plaza de Araure verdad \nlook contesto top\nMi amoor\nnice\nHi\nHi\nMerry christmas xD\nâ\x9c¨â\x9c¨â\x9c¨\nAll.', 'Pretty\nDope stylo as always Dua this is really elegant and so freaking you amazing  love it \nSo hottt â\x9d¤\nOne of my fevaleti gilo\nAffan Raiyan Siddiqui feshana gorer\nSo beautiful\nâ\x99Ľď¸\x8fâ\x99Ľď¸\x8fâ\x99Ľď¸\x8f\nVamos Argentina\nŘ§Ř\xadŮ\x84Ů\x8a ŘŻŘšŘ§ŘĄ Ů\x84Ř¨Ů\x87 \nThis is exactly how we sit in the toilet \n×˘×\x95×\x9b×¨×Ş ×\x94×Š×\xa0×\x94 \n\nthe biggest & sweetest snowflake on earth ...\nMeziana endk dik lpijama Saraha \n\n\nâ\x9d¤ď¸\x8f\nâ\x9d¤ď¸\x8fâ\x9d¤ď¸\x8f\nâ\x9d¤\nâ\x9d¤ď¸\x8f\n\nâ\x9d¤â\x9d¤\nâ\x99Ľď¸\x8fâ\x99Ľď¸\x8f\n love and affection to the beautiful Dua Lipa \nPerfect\nTable cloth ka ghorl?', 'Te quiero saludos desde MĂŠxico  :3\nBelllaaa\nPreciosaaaaa\nMe gustas tanto\nAaa erws tan previosaaaa\nOh yea\nIâ\x9d¤ď¸\x8fU Dua Lipa.', "Preciosaa \nYou're an angel â\x9d¤ď¸\x8fâ\x9d¤ď¸\x8fâ\x9d¤ď¸\x8f\nwow\nâ\x9d¤ď¸\x8fâ\x9d¤ď¸\x8f\nAna Clara Morgado\nLove you dua\nHermosas imĂĄgenes ..", 'I wish I could bend my knees and sqaut like that again.', 'Love to you and your family Ms Dua Lipa.', 'I love you.', 'Katie Joseph\nSiĂŠntate en mi cara bb\nPretty â\x9d¤\nA\nYou are an angel \n\n\nPreciosaaaaaa â\x9d¤ď¸\x8f\nTe amo mucho mi vida â\x9d¤ď¸\x8f\nMy Princess  \n\n\n\n\n\nQ hermoso todo\nEso que puta \nCristhian Jovan Rodriguez\n\n\nCome,  ...

# %%
porter_stemmer = PorterStemmer()

# %%
nltk_tokens = nltk.word_tokenize(text)

# %%
for w in nltk_tokens: 
    print ("Actual: % s Stem: % s" % (w, porter_stemmer.stem(w)))
# Out:
# Actual: Steven Stem: steven
# Actual: Janse Stem: jans
# Actual: je Stem: je
# Actual: kerst Stem: kerst
# Actual: engel Stem: engel
# Actual: zit Stem: zit
# Actual: klaar Stem: klaar
# Actual: , Stem: ,
# Actual: waar Stem: waar
# Actual: ben Stem: ben
# Actual: jij Stem: jij
# Actual: ? Stem: ?
# Actual: ŘŻŘšŘ§ Stem: řżřšř§
# Actual: ŮŮŘ¨Ř§ Stem: ůůř¨ř§
# Actual: ááááááĄá¨á Stem: ááááááąá¨á
# Actual: áŽáá Stem: ážáá
# Actual: ? Stem: ?
# Actual: Look Stem: look
# Actual: always Stem: alway
# Actual: good Stem: good
# Actual: . Stem: .
# Actual: magical Stem: magic
# Actual: Beautiful Stem: beauti
# Actual: Mau Stem: mau
# Actual: Pavia Stem: pavia
# Actual: Jr. Stem: jr.
# Actual: Feliz Stem: feliz
# Actual: navidad Stem: navidad
# Actual: Te Stem: Te
# Actual: hablan Stem: hablan
# Actual: Jorge Stem: jorg
# Actual: Alberto Stem: alberto
# Actual: Vadillo Stem: vadillo
# Actual: Ramirez Stem: ramirez
# Actual: Goegeous Stem: goegeou
# Actual: . Stem: .
# Actual: O Stem: O
# Actual: gon Stem: gon
# Actual: the Stem: the
# Actual: biggest Stem: biggest
# Actual: & Stem: &
# Actual: sweetest Stem: sweetest
# Actual: snowflake Stem: snowflak
# Actual: on Stem: on
# Actual: earth Stem: earth
# Actual: . Stem: .
# Actual: ááááááĄá¨á Stem: ááááááąá¨á
# Actual: áŽáá Stem: ážáá
# Actual: ? Stem: ?
# Actual: I Stem: I
# Actual: love Stem: love
# Actual: that Stem: that
# Actual: tree Stem: tree
# Actual: . Stem: .
# Actual: I Stem: I
# Actual: seriously Stem: serious
# Actual: think Stem: think
# Actual: that Stem: that
# Actual: right Stem: right
# Actual: now Stem: now
# Actual: ... Stem: ...
# Actual: you Stem: you
# Actual: 're Stem: 're
# Actual: the Stem: the
# Actual: prettiest Stem: prettiest
# Actual: female Stem: femal
# Actual: artist Stem: artist
# Actual: in Stem: in
# Actual: the Stem: the
# Actual: world Stem: world
# Actual: . Stem: .
# Actual: What Stem: what
# Actual: a Stem: a
# Actual: wonderful Stem: wonder
# Actual: style Stem: style
# Actual: Liana Stem: liana
# Actual: Lord Stem: lord
# Actual: Fantastique Stem: fantastiqu
# Actual: Linda Stem: linda
# Actual: Dua Stem: dua
# Actual: lipa Stem: lipa
# Actual: Reece Stem: reec
# Actual: Williams Stem: william
# Actual: Whereâs Stem: whereâ
# Actual: your Stem: your
# Actual: soul Stem: soul
# Actual: girl Stem: girl
# Actual: ? Stem: ?
# Actual: ! Stem: !
# Actual: Merry Stem: merri
# Actual: Christmas Stem: christma
# Actual: â¤ď¸ Stem: â¤ď¸
# Actual: si Stem: si
# Actual: belle Stem: bell
# Actual: so Stem: so
# Actual: beautiful Stem: beauti
# Actual: bellissima Stem: bellissima
# Actual: Beautiful Stem: beauti
# Actual: She Stem: she
# Actual: 's Stem: 's
# Actual: FIREEEE Stem: fireee
# Actual: Hasta Stem: hasta
# Actual: que Stem: que
# Actual: al Stem: al
# Actual: fin Stem: fin
# Actual: te Stem: te
# Actual: pusiste Stem: pusist
# Actual: el Stem: el
# Actual: conjunto Stem: conjunto
# Actual: que Stem: que
# Actual: te Stem: te
# Actual: compre Stem: compr
# Actual: â¤ď¸ Stem: â¤ď¸
# Actual: Beautiful Stem: beauti
# Actual: Oyeeee Stem: oyeee
# Actual: Arin Stem: arin
# Actual: Lowrance Stem: lowranc
# Actual: Costa Stem: costa
# Actual: she Stem: she
# Actual: is Stem: is
# Actual: my Stem: my
# Actual: Girl Stem: girl
# Actual: â¤ď¸ Stem: â¤ď¸
# Actual: A Stem: A
# Actual: Gg Stem: Gg
# Actual: 1 Stem: 1
# Actual: ŮŘąŮ Stem: ůřąů
# Actual: Livia Stem: livia
# Actual: Dinehart Stem: dinehart
# Actual: thought Stem: thought
# Actual: this Stem: thi
# Actual: was Stem: wa
# Actual: you Stem: you
# Actual: Linda Stem: linda
# Actual: Etai Stem: etai
# Actual: Zilberman Stem: zilberman
# Actual: ×× Stem: ××
# Actual: ×××× Stem: ××××
# Actual: ×˘× Stem: ×˘×
# Actual: ××× Stem: ×××
# Actual: ×××Š×××Ş Stem: ×××š×××ş
# Actual: ×××¤× Stem: ×××¤×
# Actual: ××××Ş Stem: ××××ş
# Actual: ×× Stem: ××
# Actual: ×˘××Š× Stem: ×˘××š×
# Actual: ×× Stem: ××
# Actual: ××××§ Stem: ××××§
# Actual: ×××××˘×¨×Ş Stem: ×××××˘×¨×ş
# Actual: Prettyyyyyy Stem: prettyyyyyy
# Actual: Desearia Stem: desearia
# Actual: estar Stem: estar
# Actual: contigo Stem: contigo
# Actual: I Stem: I
# Actual: thought Stem: thought
# Actual: u Stem: u
# Actual: were Stem: were
# Actual: dixie Stem: dixi
# Actual: Maria Stem: maria
# Actual: Antonia Stem: antonia
# Actual: Rosa Stem: rosa
# Actual: Braga Stem: braga
# Actual: Wah Stem: wah
# Actual: ! Stem: !
# Actual: Christmas Stem: christma
# Actual: is Stem: is
# Actual: coming Stem: come
# Actual: á Stem: á
# Actual: á Stem: á
# Actual: áááááá Stem: áááááá
# Actual: áááŤáááĄ Stem: áááťáááą
# Actual: áŽáá Stem: ážáá
# Actual: â¨DLJDâ¨ď¸ Stem: â¨dljdâ¨ď¸
# Actual: ... Stem: ...
# Actual: ' Stem: '
# Actual: I Stem: I
# Actual: wish Stem: wish
# Actual: you Stem: you
# Actual: a Stem: a
# Actual: Merry Stem: merri
# Actual: Christmas Stem: christma
# Actual: ! Stem: !
# Actual: I Stem: I
# Actual: wish Stem: wish
# Actual: you Stem: you
# Actual: a Stem: a
# Actual: merry Stem: merri
# Actual: Christmas Stem: christma
# Actual: ! Stem: !
# Actual: and Stem: and
# Actual: , Stem: ,
# Actual: a Stem: a
# Actual: happy Stem: happi
# Actual: New Stem: new
# Actual: Year Stem: year
# Actual: ! Stem: !
# Actual: 'Merry Stem: 'merri
# Actual: Christmas Stem: christma
# Actual: Ms Stem: Ms
# Actual: Dua Stem: dua
# Actual: ! Stem: !
# Actual: â¨âď¸ââ¨Merry Stem: â¨âď¸ââ¨merri
# Actual: Christmas Stem: christma
# Actual: Dear Stem: dear
# Actual: Jimmy Stem: jimmi
# Actual: ! Stem: !
# Actual: â¨âď¸ââ¨ Stem: â¨âď¸ââ¨
# Actual: would Stem: would
# Actual: you Stem: you
# Actual: kiss Stem: kiss
# Actual: me Stem: me
# Actual: ? Stem: ?
# Actual: GG Stem: GG
# Actual: Wow Stem: wow
# Actual: Beautiful Stem: beauti
# Actual: xxx Stem: xxx
# Actual: Um Stem: Um
# Actual: beijo Stem: beijo
# Actual: meu Stem: meu
# Actual: amor Stem: amor
# Actual: ! Stem: !
# Actual: ! Stem: !
# Actual: ! Stem: !
# Actual: ! Stem: !
# Actual: ! Stem: !
# Actual: ! Stem: !
# Actual: ! Stem: !
# Actual: Hola Stem: hola
# Actual: mi Stem: mi
# Actual: reina Stem: reina
# Actual: Dios Stem: dio
# Actual: te Stem: te
# Actual: cuide Stem: cuid
# Actual: , Stem: ,
# Actual: te Stem: te
# Actual: estamos Stem: estamo
# Actual: esperando Stem: esperando
# Actual: para Stem: para
# Actual: la Stem: la
# Actual: cena Stem: cena
# Actual: navideĂąa Stem: navideăąa
# Actual: mi Stem: mi
# Actual: princesa Stem: princesa
# Actual: Ř§ŮŮŘ§ Stem: ř§ůůř§
# Actual: ŮŘŻŘ§ Stem: ůřżř§
# Actual: Ř§ŘŞŘšŘŻŮŮ Stem: ř§řşřšřżůů
# Actual: Ů Stem: Ů
# Actual: ŮŘ˛ŮŮ Stem: ůř˛ůů
# Actual: ŘľŮŘąŘŠ Stem: řľůřąřš
# Actual: ŘšŘŻŮŘŠ Stem: řšřżůřš
# Actual: Pray Stem: pray
# Actual: for Stem: for
# Actual: me Stem: me
# Actual: , Stem: ,
# Actual: my Stem: my
# Actual: love Stem: love
# Actual: . Stem: .
# Actual: ŘŞŮŘ§Ř¨Ů Stem: řşůř§ř¨ů
# Actual: Ů Stem: Ů
# Actual: ŘŞŮ Stem: řşů
# Actual: ŮŮŘ´ŘŠ Stem: ůůř´řš
# Actual: Ř´ŘąŘ´Ů Stem: ř´řąř´ů
# Actual: Ř§ŮŘłŮŘąŘŠ Stem: ř§ůřłůřąřš
# Actual: ŘšŮŘ§ Stem: řšůř§
# Actual: I Stem: I
# Actual: love Stem: love
# Actual: you Stem: you
# Actual: dua Stem: dua
# Actual: â¤ Stem: â¤
# Actual: Nice Stem: nice
# Actual: Luka Stem: luka
# Actual: Jureta Stem: jureta
# Actual: radi Stem: radi
# Actual: li Stem: li
# Actual: se Stem: se
# Actual: o Stem: o
# Actual: stablou Stem: stablou
# Actual: na Stem: na
# Actual: vinkovec Stem: vinkovec
# Actual: corso Stem: corso
# Actual: ? Stem: ?
# Actual: ZaĹĄto Stem: zaĺąto
# Actual: dua Stem: dua
# Actual: nikad Stem: nikad
# Actual: ne Stem: ne
# Actual: s Stem: s
# Actual: mi Stem: mi
# Actual: vincovec Stem: vincovec
# Actual: shopping Stem: shop
# Actual: mall Stem: mall
# Actual: ? Stem: ?
# Actual: U Stem: U
# Actual: r Stem: r
# Actual: beautifuul Stem: beautifuul
# Actual: áŁáŁ Stem: áłáł
# Actual: ááá Stem: ááá
# Actual: ááááááááá Stem: ááááááááá
# Actual: â¤ď¸ Stem: â¤ď¸
# Actual: se Stem: se
# Actual: mi Stem: mi
# Actual: amiga Stem: amiga
# Actual: por Stem: por
# Actual: favor Stem: favor
# Actual: Benjamin Stem: benjamin
# Actual: Trejo Stem: trejo
# Actual: â¤â¤â¤â¤ Stem: â¤â¤â¤â¤
# Actual: Amo Stem: amo
# Actual: que Stem: que
# Actual: es Stem: es
# Actual: tan Stem: tan
# Actual: bella Stem: bella
# Actual: quĂ˘Ěn Stem: quă˘ěn
# Actual: caĚi Stem: caěi
# Actual: khÄn Stem: khän
# Actual: traĚi Stem: traěi
# Actual: baĚn Stem: baěn
# Actual: haĚ Stem: haě
# Actual: : Stem: :
# Actual: ' Stem: '
# Actual: ( Stem: (
# Actual: Wow Stem: wow
# Actual: you Stem: you
# Actual: are Stem: are
# Actual: my Stem: my
# Actual: wonder Stem: wonder
# Actual: woman Stem: woman
# Actual: . Stem: .
# Actual: Merry Stem: merri
# Actual: Christmas Stem: christma
# Actual: my Stem: my
# Actual: love Stem: love
# Actual: Eso Stem: eso
# Actual: es Stem: es
# Actual: en Stem: en
# Actual: la Stem: la
# Actual: plaza Stem: plaza
# Actual: de Stem: de
# Actual: Araure Stem: araur
# Actual: verdad Stem: verdad
# Actual: look Stem: look
# Actual: contesto Stem: contesto
# Actual: top Stem: top
# Actual: Mi Stem: Mi
# Actual: amoor Stem: amoor
# Actual: nice Stem: nice
# Actual: Hi Stem: Hi
# Actual: Hi Stem: Hi
# Actual: Merry Stem: merri
# Actual: christmas Stem: christma
# Actual: xD Stem: xD
# Actual: â¨â¨â¨ Stem: â¨â¨â¨
# Actual: All Stem: all
# Actual: . Stem: .
# Actual: Pretty Stem: pretti
# Actual: Dope Stem: dope
# Actual: stylo Stem: stylo
# Actual: as Stem: as
# Actual: always Stem: alway
# Actual: Dua Stem: dua
# Actual: this Stem: thi
# Actual: is Stem: is
# Actual: really Stem: realli
# Actual: elegant Stem: eleg
# Actual: and Stem: and
# Actual: so Stem: so
# Actual: freaking Stem: freak
# Actual: you Stem: you
# Actual: amazing Stem: amaz
# Actual: love Stem: love
# Actual: it Stem: it
# Actual: So Stem: So
# Actual: hottt Stem: hottt
# Actual: â¤ Stem: â¤
# Actual: One Stem: one
# Actual: of Stem: of
# Actual: my Stem: my
# Actual: fevaleti Stem: fevaleti
# Actual: gilo Stem: gilo
# Actual: Affan Stem: affan
# Actual: Raiyan Stem: raiyan
# Actual: Siddiqui Stem: siddiqui
# Actual: feshana Stem: feshana
# Actual: gorer Stem: gorer
# Actual: So Stem: So
# Actual: beautiful Stem: beauti
# Actual: âĽď¸âĽď¸âĽď¸ Stem: âľď¸âľď¸âľď¸
# Actual: Vamos Stem: vamo
# Actual: Argentina Stem: argentina
# Actual: Ř§Ř­ŮŮ Stem: ř§ř­ůů
# Actual: ŘŻŘšŘ§ŘĄ Stem: řżřšř§řą
# Actual: ŮŘ¨Ů Stem: ůř¨ů
# Actual: This Stem: thi
# Actual: is Stem: is
# Actual: exactly Stem: exactli
# Actual: how Stem: how
# Actual: we Stem: we
# Actual: sit Stem: sit
# Actual: in Stem: in
# Actual: the Stem: the
# Actual: toilet Stem: toilet
# Actual: ×˘×××¨×Ş Stem: ×˘×××¨×ş
# Actual: ××Š× Stem: ××š×
# Actual: × Stem: ×
# Actual: the Stem: the
# Actual: biggest Stem: biggest
# Actual: & Stem: &
# Actual: sweetest Stem: sweetest
# Actual: snowflake Stem: snowflak
# Actual: on Stem: on
# Actual: earth Stem: earth
# Actual: ... Stem: ...
# Actual: Meziana Stem: meziana
# Actual: endk Stem: endk
# Actual: dik Stem: dik
# Actual: lpijama Stem: lpijama
# Actual: Saraha Stem: saraha
# Actual: â¤ď¸ Stem: â¤ď¸
# Actual: â¤ď¸â¤ď¸ Stem: â¤ď¸â¤ď¸
# Actual: â¤ Stem: â¤
# Actual: â¤ď¸ Stem: â¤ď¸
# Actual: â¤â¤ Stem: â¤â¤
# Actual: âĽď¸âĽď¸ Stem: âľď¸âľď¸
# Actual: love Stem: love
# Actual: and Stem: and
# Actual: affection Stem: affect
# Actual: to Stem: to
# Actual: the Stem: the
# Actual: beautiful Stem: beauti
# Actual: Dua Stem: dua
# Actual: Lipa Stem: lipa
# Actual: Perfect Stem: perfect
# Actual: Table Stem: tabl
# Actual: cloth Stem: cloth
# Actual: ka Stem: ka
# Actual: ghorl Stem: ghorl
# Actual: ? Stem: ?
# Actual: Te Stem: Te
# Actual: quiero Stem: quiero
# Actual: saludos Stem: saludo
# Actual: desde Stem: desd
# Actual: MĂŠxico Stem: măšxico
# Actual: :3 Stem: :3
# Actual: Belllaaa Stem: belllaaa
# Actual: Preciosaaaaa Stem: preciosaaaaa
# Actual: Me Stem: Me
# Actual: gustas Stem: gusta
# Actual: tanto Stem: tanto
# Actual: Aaa Stem: aaa
# Actual: erws Stem: erw
# Actual: tan Stem: tan
# Actual: previosaaaa Stem: previosaaaa
# Actual: Oh Stem: Oh
# Actual: yea Stem: yea
# Actual: Iâ¤ď¸U Stem: iâ¤ď¸u
# Actual: Dua Stem: dua
# Actual: Lipa Stem: lipa
# Actual: . Stem: .
# Actual: Preciosaa Stem: preciosaa
# Actual: You Stem: you
# Actual: 're Stem: 're
# Actual: an Stem: an
# Actual: angel Stem: angel
# Actual: â¤ď¸â¤ď¸â¤ď¸ Stem: â¤ď¸â¤ď¸â¤ď¸
# Actual: wow Stem: wow
# Actual: â¤ď¸â¤ď¸ Stem: â¤ď¸â¤ď¸
# Actual: Ana Stem: ana
# Actual: Clara Stem: clara
# Actual: Morgado Stem: morgado
# Actual: Love Stem: love
# Actual: you Stem: you
# Actual: dua Stem: dua
# Actual: Hermosas Stem: hermosa
# Actual: imĂĄgenes Stem: imăągen
# Actual: .. Stem: ..
# Actual: I Stem: I
# Actual: wish Stem: wish
# Actual: I Stem: I
# Actual: could Stem: could
# Actual: bend Stem: bend
# Actual: my Stem: my
# Actual: knees Stem: knee
# Actual: and Stem: and
# Actual: sqaut Stem: sqaut
# Actual: like Stem: like
# Actual: that Stem: that
# Actual: again Stem: again
# Actual: . Stem: .
# Actual: Love Stem: love
# Actual: to Stem: to
# Actual: you Stem: you
# Actual: and Stem: and
# Actual: your Stem: your
# Actual: family Stem: famili
# Actual: Ms Stem: Ms
# Actual: Dua Stem: dua
# Actual: Lipa Stem: lipa
# Actual: . Stem: .
# Actual: I Stem: I
# Actual: love Stem: love
# Actual: you Stem: you
# Actual: . Stem: .
# Actual: Katie Stem: kati
# Actual: Joseph Stem: joseph
# Actual: SiĂŠntate Stem: siăšntat
# Actual: en Stem: en
# Actual: mi Stem: mi
# Actual: cara Stem: cara
# Actual: bb Stem: bb
# Actual: Pretty Stem: pretti
# Actual: â¤ Stem: â¤
# Actual: A Stem: A
# Actual: You Stem: you
# Actual: are Stem: are
# Actual: an Stem: an
# Actual: angel Stem: angel
# Actual: Preciosaaaaaa Stem: preciosaaaaaa
# Actual: â¤ď¸ Stem: â¤ď¸
# Actual: Te Stem: Te
# Actual: amo Stem: amo
# Actual: mucho Stem: mucho
# Actual: mi Stem: mi
# Actual: vida Stem: vida
# Actual: â¤ď¸ Stem: â¤ď¸
# Actual: My Stem: My
# Actual: Princess Stem: princess
# Actual: Q Stem: Q
# Actual: hermoso Stem: hermoso
# Actual: todo Stem: todo
# Actual: Eso Stem: eso
# Actual: que Stem: que
# Actual: puta Stem: puta
# Actual: Cristhian Stem: cristhian
# Actual: Jovan Stem: jovan
# Actual: Rodriguez Stem: rodriguez
# Actual: Come Stem: come
# Actual: , Stem: ,
# Actual: love Stem: love
# Actual: . Stem: .
# Actual: Kpuca Stem: kpuca
# Actual: te Stem: te
# Actual: verdha Stem: verdha
# Actual: me Stem: me
# Actual: pak Stem: pak
# Actual: take Stem: take
# Actual: dhe Stem: dhe
# Actual: me Stem: me
# Actual: lidhsa Stem: lidhsa
# Actual: ose Stem: ose
# Actual: me Stem: me
# Actual: shnoll Stem: shnoll
# Actual: . Stem: .
# Actual: Kpucat Stem: kpucat
# Actual: katastrof Stem: katastrof
# Actual: Dua Stem: dua
# Actual: Lipa Stem: lipa
# Actual: â¤ Stem: â¤
# Actual: Linda Stem: linda
# Actual: miamor Stem: miamor
# Actual: Diosa Stem: diosa
# Actual: de Stem: de
# Actual: mi Stem: mi
# Actual: corazĂłn Stem: corazăłn
# Actual: you Stem: you
# Actual: are Stem: are
# Actual: incredibly Stem: incred
# Actual: beautiful Stem: beauti
# Actual: Let Stem: let
# Actual: me Stem: me
# Actual: give Stem: give
# Actual: it Stem: it
# Actual: to Stem: to
# Actual: you Stem: you
# Actual: , Stem: ,
# Actual: while Stem: while
# Actual: you Stem: you
# Actual: take Stem: take
# Actual: it Stem: it
# Actual: willingly Stem: willingli
# Actual: dua Stem: dua
# Actual: lipa Stem: lipa
# Actual: Dua Stem: dua
# Actual: Lipa Stem: lipa
# Actual: Always Stem: alway
# Actual: so Stem: so
# Actual: beautifulâ¤ď¸ Stem: beautifulâ¤ď¸
# Actual: You Stem: you
# Actual: are Stem: are
# Actual: very Stem: veri
# Actual: pretty Stem: pretti
# Actual: , Stem: ,
# Actual: I Stem: I
# Actual: love Stem: love
# Actual: you Stem: you
# Actual: Dua Stem: dua
# Actual: â¤ď¸â¤ď¸â¤ď¸ Stem: â¤ď¸â¤ď¸â¤ď¸
# Actual: Beautiful Stem: beauti
# Actual: ... Stem: ...
# Actual: I Stem: I
# Actual: love Stem: love
# Actual: this Stem: thi
# Actual: outfit Stem: outfit
# Actual: . Stem: .

# %%
wordnet_lemmatizer = WordNetLemmatizer() 
nltk_tokens = nltk.word_tokenize(text)

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HOME\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
for w in nltk_tokens: 
    print ("Actual: % s Lemma: % s" % (w, wordnet_lemmatizer.lemmatize(w)))
# Out:
# Actual: Steven Lemma: Steven
# Actual: Janse Lemma: Janse
# Actual: je Lemma: je
# Actual: kerst Lemma: kerst
# Actual: engel Lemma: engel
# Actual: zit Lemma: zit
# Actual: klaar Lemma: klaar
# Actual: , Lemma: ,
# Actual: waar Lemma: waar
# Actual: ben Lemma: ben
# Actual: jij Lemma: jij
# Actual: ? Lemma: ?
# Actual: ŘŻŘšŘ§ Lemma: ŘŻŘšŘ§
# Actual: ŮŮŘ¨Ř§ Lemma: ŮŮŘ¨Ř§
# Actual: ááááááĄá¨á Lemma: ááááááĄá¨á
# Actual: áŽáá Lemma: áŽáá
# Actual: ? Lemma: ?
# Actual: Look Lemma: Look
# Actual: always Lemma: always
# Actual: good Lemma: good
# Actual: . Lemma: .
# Actual: magical Lemma: magical
# Actual: Beautiful Lemma: Beautiful
# Actual: Mau Lemma: Mau
# Actual: Pavia Lemma: Pavia
# Actual: Jr. Lemma: Jr.
# Actual: Feliz Lemma: Feliz
# Actual: navidad Lemma: navidad
# Actual: Te Lemma: Te
# Actual: hablan Lemma: hablan
# Actual: Jorge Lemma: Jorge
# Actual: Alberto Lemma: Alberto
# Actual: Vadillo Lemma: Vadillo
# Actual: Ramirez Lemma: Ramirez
# Actual: Goegeous Lemma: Goegeous
# Actual: . Lemma: .
# Actual: O Lemma: O
# Actual: gon Lemma: gon
# Actual: the Lemma: the
# Actual: biggest Lemma: biggest
# Actual: & Lemma: &
# Actual: sweetest Lemma: sweetest
# Actual: snowflake Lemma: snowflake
# Actual: on Lemma: on
# Actual: earth Lemma: earth
# Actual: . Lemma: .
# Actual: ááááááĄá¨á Lemma: ááááááĄá¨á
# Actual: áŽáá Lemma: áŽáá
# Actual: ? Lemma: ?
# Actual: I Lemma: I
# Actual: love Lemma: love
# Actual: that Lemma: that
# Actual: tree Lemma: tree
# Actual: . Lemma: .
# Actual: I Lemma: I
# Actual: seriously Lemma: seriously
# Actual: think Lemma: think
# Actual: that Lemma: that
# Actual: right Lemma: right
# Actual: now Lemma: now
# Actual: ... Lemma: ...
# Actual: you Lemma: you
# Actual: 're Lemma: 're
# Actual: the Lemma: the
# Actual: prettiest Lemma: prettiest
# Actual: female Lemma: female
# Actual: artist Lemma: artist
# Actual: in Lemma: in
# Actual: the Lemma: the
# Actual: world Lemma: world
# Actual: . Lemma: .
# Actual: What Lemma: What
# Actual: a Lemma: a
# Actual: wonderful Lemma: wonderful
# Actual: style Lemma: style
# Actual: Liana Lemma: Liana
# Actual: Lord Lemma: Lord
# Actual: Fantastique Lemma: Fantastique
# Actual: Linda Lemma: Linda
# Actual: Dua Lemma: Dua
# Actual: lipa Lemma: lipa
# Actual: Reece Lemma: Reece
# Actual: Williams Lemma: Williams
# Actual: Whereâs Lemma: Whereâs
# Actual: your Lemma: your
# Actual: soul Lemma: soul
# Actual: girl Lemma: girl
# Actual: ? Lemma: ?
# Actual: ! Lemma: !
# Actual: Merry Lemma: Merry
# Actual: Christmas Lemma: Christmas
# Actual: â¤ď¸ Lemma: â¤ď¸
# Actual: si Lemma: si
# Actual: belle Lemma: belle
# Actual: so Lemma: so
# Actual: beautiful Lemma: beautiful
# Actual: bellissima Lemma: bellissima
# Actual: Beautiful Lemma: Beautiful
# Actual: She Lemma: She
# Actual: 's Lemma: 's
# Actual: FIREEEE Lemma: FIREEEE
# Actual: Hasta Lemma: Hasta
# Actual: que Lemma: que
# Actual: al Lemma: al
# Actual: fin Lemma: fin
# Actual: te Lemma: te
# Actual: pusiste Lemma: pusiste
# Actual: el Lemma: el
# Actual: conjunto Lemma: conjunto
# Actual: que Lemma: que
# Actual: te Lemma: te
# Actual: compre Lemma: compre
# Actual: â¤ď¸ Lemma: â¤ď¸
# Actual: Beautiful Lemma: Beautiful
# Actual: Oyeeee Lemma: Oyeeee
# Actual: Arin Lemma: Arin
# Actual: Lowrance Lemma: Lowrance
# Actual: Costa Lemma: Costa
# Actual: she Lemma: she
# Actual: is Lemma: is
# Actual: my Lemma: my
# Actual: Girl Lemma: Girl
# Actual: â¤ď¸ Lemma: â¤ď¸
# Actual: A Lemma: A
# Actual: Gg Lemma: Gg
# Actual: 1 Lemma: 1
# Actual: ŮŘąŮ Lemma: ŮŘąŮ
# Actual: Livia Lemma: Livia
# Actual: Dinehart Lemma: Dinehart
# Actual: thought Lemma: thought
# Actual: this Lemma: this
# Actual: was Lemma: wa
# Actual: you Lemma: you
# Actual: Linda Lemma: Linda
# Actual: Etai Lemma: Etai
# Actual: Zilberman Lemma: Zilberman
# Actual: ×× Lemma: ××
# Actual: ×××× Lemma: ××××
# Actual: ×˘× Lemma: ×˘×
# Actual: ××× Lemma: ×××
# Actual: ×××Š×××Ş Lemma: ×××Š×××Ş
# Actual: ×××¤× Lemma: ×××¤×
# Actual: ××××Ş Lemma: ××××Ş
# Actual: ×× Lemma: ××
# Actual: ×˘××Š× Lemma: ×˘××Š×
# Actual: ×× Lemma: ××
# Actual: ××××§ Lemma: ××××§
# Actual: ×××××˘×¨×Ş Lemma: ×××××˘×¨×Ş
# Actual: Prettyyyyyy Lemma: Prettyyyyyy
# Actual: Desearia Lemma: Desearia
# Actual: estar Lemma: estar
# Actual: contigo Lemma: contigo
# Actual: I Lemma: I
# Actual: thought Lemma: thought
# Actual: u Lemma: u
# Actual: were Lemma: were
# Actual: dixie Lemma: dixie
# Actual: Maria Lemma: Maria
# Actual: Antonia Lemma: Antonia
# Actual: Rosa Lemma: Rosa
# Actual: Braga Lemma: Braga
# Actual: Wah Lemma: Wah
# Actual: ! Lemma: !
# Actual: Christmas Lemma: Christmas
# Actual: is Lemma: is
# Actual: coming Lemma: coming
# Actual: á Lemma: á
# Actual: á Lemma: á
# Actual: áááááá Lemma: áááááá
# Actual: áááŤáááĄ Lemma: áááŤáááĄ
# Actual: áŽáá Lemma: áŽáá
# Actual: â¨DLJDâ¨ď¸ Lemma: â¨DLJDâ¨ď¸
# Actual: ... Lemma: ...
# Actual: ' Lemma: '
# Actual: I Lemma: I
# Actual: wish Lemma: wish
# Actual: you Lemma: you
# Actual: a Lemma: a
# Actual: Merry Lemma: Merry
# Actual: Christmas Lemma: Christmas
# Actual: ! Lemma: !
# Actual: I Lemma: I
# Actual: wish Lemma: wish
# Actual: you Lemma: you
# Actual: a Lemma: a
# Actual: merry Lemma: merry
# Actual: Christmas Lemma: Christmas
# Actual: ! Lemma: !
# Actual: and Lemma: and
# Actual: , Lemma: ,
# Actual: a Lemma: a
# Actual: happy Lemma: happy
# Actual: New Lemma: New
# Actual: Year Lemma: Year
# Actual: ! Lemma: !
# Actual: 'Merry Lemma: 'Merry
# Actual: Christmas Lemma: Christmas
# Actual: Ms Lemma: Ms
# Actual: Dua Lemma: Dua
# Actual: ! Lemma: !
# Actual: â¨âď¸ââ¨Merry Lemma: â¨âď¸ââ¨Merry
# Actual: Christmas Lemma: Christmas
# Actual: Dear Lemma: Dear
# Actual: Jimmy Lemma: Jimmy
# Actual: ! Lemma: !
# Actual: â¨âď¸ââ¨ Lemma: â¨âď¸ââ¨
# Actual: would Lemma: would
# Actual: you Lemma: you
# Actual: kiss Lemma: kiss
# Actual: me Lemma: me
# Actual: ? Lemma: ?
# Actual: GG Lemma: GG
# Actual: Wow Lemma: Wow
# Actual: Beautiful Lemma: Beautiful
# Actual: xxx Lemma: xxx
# Actual: Um Lemma: Um
# Actual: beijo Lemma: beijo
# Actual: meu Lemma: meu
# Actual: amor Lemma: amor
# Actual: ! Lemma: !
# Actual: ! Lemma: !
# Actual: ! Lemma: !
# Actual: ! Lemma: !
# Actual: ! Lemma: !
# Actual: ! Lemma: !
# Actual: ! Lemma: !
# Actual: Hola Lemma: Hola
# Actual: mi Lemma: mi
# Actual: reina Lemma: reina
# Actual: Dios Lemma: Dios
# Actual: te Lemma: te
# Actual: cuide Lemma: cuide
# Actual: , Lemma: ,
# Actual: te Lemma: te
# Actual: estamos Lemma: estamos
# Actual: esperando Lemma: esperando
# Actual: para Lemma: para
# Actual: la Lemma: la
# Actual: cena Lemma: cena
# Actual: navideĂąa Lemma: navideĂąa
# Actual: mi Lemma: mi
# Actual: princesa Lemma: princesa
# Actual: Ř§ŮŮŘ§ Lemma: Ř§ŮŮŘ§
# Actual: ŮŘŻŘ§ Lemma: ŮŘŻŘ§
# Actual: Ř§ŘŞŘšŘŻŮŮ Lemma: Ř§ŘŞŘšŘŻŮŮ
# Actual: Ů Lemma: Ů
# Actual: ŮŘ˛ŮŮ Lemma: ŮŘ˛ŮŮ
# Actual: ŘľŮŘąŘŠ Lemma: ŘľŮŘąŘŠ
# Actual: ŘšŘŻŮŘŠ Lemma: ŘšŘŻŮŘŠ
# Actual: Pray Lemma: Pray
# Actual: for Lemma: for
# Actual: me Lemma: me
# Actual: , Lemma: ,
# Actual: my Lemma: my
# Actual: love Lemma: love
# Actual: . Lemma: .
# Actual: ŘŞŮŘ§Ř¨Ů Lemma: ŘŞŮŘ§Ř¨Ů
# Actual: Ů Lemma: Ů
# Actual: ŘŞŮ Lemma: ŘŞŮ
# Actual: ŮŮŘ´ŘŠ Lemma: ŮŮŘ´ŘŠ
# Actual: Ř´ŘąŘ´Ů Lemma: Ř´ŘąŘ´Ů
# Actual: Ř§ŮŘłŮŘąŘŠ Lemma: Ř§ŮŘłŮŘąŘŠ
# Actual: ŘšŮŘ§ Lemma: ŘšŮŘ§
# Actual: I Lemma: I
# Actual: love Lemma: love
# Actual: you Lemma: you
# Actual: dua Lemma: dua
# Actual: â¤ Lemma: â¤
# Actual: Nice Lemma: Nice
# Actual: Luka Lemma: Luka
# Actual: Jureta Lemma: Jureta
# Actual: radi Lemma: radi
# Actual: li Lemma: li
# Actual: se Lemma: se
# Actual: o Lemma: o
# Actual: stablou Lemma: stablou
# Actual: na Lemma: na
# Actual: vinkovec Lemma: vinkovec
# Actual: corso Lemma: corso
# Actual: ? Lemma: ?
# Actual: ZaĹĄto Lemma: ZaĹĄto
# Actual: dua Lemma: dua
# Actual: nikad Lemma: nikad
# Actual: ne Lemma: ne
# Actual: s Lemma: s
# Actual: mi Lemma: mi
# Actual: vincovec Lemma: vincovec
# Actual: shopping Lemma: shopping
# Actual: mall Lemma: mall
# Actual: ? Lemma: ?
# Actual: U Lemma: U
# Actual: r Lemma: r
# Actual: beautifuul Lemma: beautifuul
# Actual: áŁáŁ Lemma: áŁáŁ
# Actual: ááá Lemma: ááá
# Actual: ááááááááá Lemma: ááááááááá
# Actual: â¤ď¸ Lemma: â¤ď¸
# Actual: se Lemma: se
# Actual: mi Lemma: mi
# Actual: amiga Lemma: amiga
# Actual: por Lemma: por
# Actual: favor Lemma: favor
# Actual: Benjamin Lemma: Benjamin
# Actual: Trejo Lemma: Trejo
# Actual: â¤â¤â¤â¤ Lemma: â¤â¤â¤â¤
# Actual: Amo Lemma: Amo
# Actual: que Lemma: que
# Actual: es Lemma: e
# Actual: tan Lemma: tan
# Actual: bella Lemma: bella
# Actual: quĂ˘Ěn Lemma: quĂ˘Ěn
# Actual: caĚi Lemma: caĚi
# Actual: khÄn Lemma: khÄn
# Actual: traĚi Lemma: traĚi
# Actual: baĚn Lemma: baĚn
# Actual: haĚ Lemma: haĚ
# Actual: : Lemma: :
# Actual: ' Lemma: '
# Actual: ( Lemma: (
# Actual: Wow Lemma: Wow
# Actual: you Lemma: you
# Actual: are Lemma: are
# Actual: my Lemma: my
# Actual: wonder Lemma: wonder
# Actual: woman Lemma: woman
# Actual: . Lemma: .
# Actual: Merry Lemma: Merry
# Actual: Christmas Lemma: Christmas
# Actual: my Lemma: my
# Actual: love Lemma: love
# Actual: Eso Lemma: Eso
# Actual: es Lemma: e
# Actual: en Lemma: en
# Actual: la Lemma: la
# Actual: plaza Lemma: plaza
# Actual: de Lemma: de
# Actual: Araure Lemma: Araure
# Actual: verdad Lemma: verdad
# Actual: look Lemma: look
# Actual: contesto Lemma: contesto
# Actual: top Lemma: top
# Actual: Mi Lemma: Mi
# Actual: amoor Lemma: amoor
# Actual: nice Lemma: nice
# Actual: Hi Lemma: Hi
# Actual: Hi Lemma: Hi
# Actual: Merry Lemma: Merry
# Actual: christmas Lemma: christmas
# Actual: xD Lemma: xD
# Actual: â¨â¨â¨ Lemma: â¨â¨â¨
# Actual: All Lemma: All
# Actual: . Lemma: .
# Actual: Pretty Lemma: Pretty
# Actual: Dope Lemma: Dope
# Actual: stylo Lemma: stylo
# Actual: as Lemma: a
# Actual: always Lemma: always
# Actual: Dua Lemma: Dua
# Actual: this Lemma: this
# Actual: is Lemma: is
# Actual: really Lemma: really
# Actual: elegant Lemma: elegant
# Actual: and Lemma: and
# Actual: so Lemma: so
# Actual: freaking Lemma: freaking
# Actual: you Lemma: you
# Actual: amazing Lemma: amazing
# Actual: love Lemma: love
# Actual: it Lemma: it
# Actual: So Lemma: So
# Actual: hottt Lemma: hottt
# Actual: â¤ Lemma: â¤
# Actual: One Lemma: One
# Actual: of Lemma: of
# Actual: my Lemma: my
# Actual: fevaleti Lemma: fevaleti
# Actual: gilo Lemma: gilo
# Actual: Affan Lemma: Affan
# Actual: Raiyan Lemma: Raiyan
# Actual: Siddiqui Lemma: Siddiqui
# Actual: feshana Lemma: feshana
# Actual: gorer Lemma: gorer
# Actual: So Lemma: So
# Actual: beautiful Lemma: beautiful
# Actual: âĽď¸âĽď¸âĽď¸ Lemma: âĽď¸âĽď¸âĽď¸
# Actual: Vamos Lemma: Vamos
# Actual: Argentina Lemma: Argentina
# Actual: Ř§Ř­ŮŮ Lemma: Ř§Ř­ŮŮ
# Actual: ŘŻŘšŘ§ŘĄ Lemma: ŘŻŘšŘ§ŘĄ
# Actual: ŮŘ¨Ů Lemma: ŮŘ¨Ů
# Actual: This Lemma: This
# Actual: is Lemma: is
# Actual: exactly Lemma: exactly
# Actual: how Lemma: how
# Actual: we Lemma: we
# Actual: sit Lemma: sit
# Actual: in Lemma: in
# Actual: the Lemma: the
# Actual: toilet Lemma: toilet
# Actual: ×˘×××¨×Ş Lemma: ×˘×××¨×Ş
# Actual: ××Š× Lemma: ××Š×
# Actual: × Lemma: ×
# Actual: the Lemma: the
# Actual: biggest Lemma: biggest
# Actual: & Lemma: &
# Actual: sweetest Lemma: sweetest
# Actual: snowflake Lemma: snowflake
# Actual: on Lemma: on
# Actual: earth Lemma: earth
# Actual: ... Lemma: ...
# Actual: Meziana Lemma: Meziana
# Actual: endk Lemma: endk
# Actual: dik Lemma: dik
# Actual: lpijama Lemma: lpijama
# Actual: Saraha Lemma: Saraha
# Actual: â¤ď¸ Lemma: â¤ď¸
# Actual: â¤ď¸â¤ď¸ Lemma: â¤ď¸â¤ď¸
# Actual: â¤ Lemma: â¤
# Actual: â¤ď¸ Lemma: â¤ď¸
# Actual: â¤â¤ Lemma: â¤â¤
# Actual: âĽď¸âĽď¸ Lemma: âĽď¸âĽď¸
# Actual: love Lemma: love
# Actual: and Lemma: and
# Actual: affection Lemma: affection
# Actual: to Lemma: to
# Actual: the Lemma: the
# Actual: beautiful Lemma: beautiful
# Actual: Dua Lemma: Dua
# Actual: Lipa Lemma: Lipa
# Actual: Perfect Lemma: Perfect
# Actual: Table Lemma: Table
# Actual: cloth Lemma: cloth
# Actual: ka Lemma: ka
# Actual: ghorl Lemma: ghorl
# Actual: ? Lemma: ?
# Actual: Te Lemma: Te
# Actual: quiero Lemma: quiero
# Actual: saludos Lemma: saludos
# Actual: desde Lemma: desde
# Actual: MĂŠxico Lemma: MĂŠxico
# Actual: :3 Lemma: :3
# Actual: Belllaaa Lemma: Belllaaa
# Actual: Preciosaaaaa Lemma: Preciosaaaaa
# Actual: Me Lemma: Me
# Actual: gustas Lemma: gustas
# Actual: tanto Lemma: tanto
# Actual: Aaa Lemma: Aaa
# Actual: erws Lemma: erws
# Actual: tan Lemma: tan
# Actual: previosaaaa Lemma: previosaaaa
# Actual: Oh Lemma: Oh
# Actual: yea Lemma: yea
# Actual: Iâ¤ď¸U Lemma: Iâ¤ď¸U
# Actual: Dua Lemma: Dua
# Actual: Lipa Lemma: Lipa
# Actual: . Lemma: .
# Actual: Preciosaa Lemma: Preciosaa
# Actual: You Lemma: You
# Actual: 're Lemma: 're
# Actual: an Lemma: an
# Actual: angel Lemma: angel
# Actual: â¤ď¸â¤ď¸â¤ď¸ Lemma: â¤ď¸â¤ď¸â¤ď¸
# Actual: wow Lemma: wow
# Actual: â¤ď¸â¤ď¸ Lemma: â¤ď¸â¤ď¸
# Actual: Ana Lemma: Ana
# Actual: Clara Lemma: Clara
# Actual: Morgado Lemma: Morgado
# Actual: Love Lemma: Love
# Actual: you Lemma: you
# Actual: dua Lemma: dua
# Actual: Hermosas Lemma: Hermosas
# Actual: imĂĄgenes Lemma: imĂĄgenes
# Actual: .. Lemma: ..
# Actual: I Lemma: I
# Actual: wish Lemma: wish
# Actual: I Lemma: I
# Actual: could Lemma: could
# Actual: bend Lemma: bend
# Actual: my Lemma: my
# Actual: knees Lemma: knee
# Actual: and Lemma: and
# Actual: sqaut Lemma: sqaut
# Actual: like Lemma: like
# Actual: that Lemma: that
# Actual: again Lemma: again
# Actual: . Lemma: .
# Actual: Love Lemma: Love
# Actual: to Lemma: to
# Actual: you Lemma: you
# Actual: and Lemma: and
# Actual: your Lemma: your
# Actual: family Lemma: family
# Actual: Ms Lemma: Ms
# Actual: Dua Lemma: Dua
# Actual: Lipa Lemma: Lipa
# Actual: . Lemma: .
# Actual: I Lemma: I
# Actual: love Lemma: love
# Actual: you Lemma: you
# Actual: . Lemma: .
# Actual: Katie Lemma: Katie
# Actual: Joseph Lemma: Joseph
# Actual: SiĂŠntate Lemma: SiĂŠntate
# Actual: en Lemma: en
# Actual: mi Lemma: mi
# Actual: cara Lemma: cara
# Actual: bb Lemma: bb
# Actual: Pretty Lemma: Pretty
# Actual: â¤ Lemma: â¤
# Actual: A Lemma: A
# Actual: You Lemma: You
# Actual: are Lemma: are
# Actual: an Lemma: an
# Actual: angel Lemma: angel
# Actual: Preciosaaaaaa Lemma: Preciosaaaaaa
# Actual: â¤ď¸ Lemma: â¤ď¸
# Actual: Te Lemma: Te
# Actual: amo Lemma: amo
# Actual: mucho Lemma: mucho
# Actual: mi Lemma: mi
# Actual: vida Lemma: vida
# Actual: â¤ď¸ Lemma: â¤ď¸
# Actual: My Lemma: My
# Actual: Princess Lemma: Princess
# Actual: Q Lemma: Q
# Actual: hermoso Lemma: hermoso
# Actual: todo Lemma: todo
# Actual: Eso Lemma: Eso
# Actual: que Lemma: que
# Actual: puta Lemma: puta
# Actual: Cristhian Lemma: Cristhian
# Actual: Jovan Lemma: Jovan
# Actual: Rodriguez Lemma: Rodriguez
# Actual: Come Lemma: Come
# Actual: , Lemma: ,
# Actual: love Lemma: love
# Actual: . Lemma: .
# Actual: Kpuca Lemma: Kpuca
# Actual: te Lemma: te
# Actual: verdha Lemma: verdha
# Actual: me Lemma: me
# Actual: pak Lemma: pak
# Actual: take Lemma: take
# Actual: dhe Lemma: dhe
# Actual: me Lemma: me
# Actual: lidhsa Lemma: lidhsa
# Actual: ose Lemma: ose
# Actual: me Lemma: me
# Actual: shnoll Lemma: shnoll
# Actual: . Lemma: .
# Actual: Kpucat Lemma: Kpucat
# Actual: katastrof Lemma: katastrof
# Actual: Dua Lemma: Dua
# Actual: Lipa Lemma: Lipa
# Actual: â¤ Lemma: â¤
# Actual: Linda Lemma: Linda
# Actual: miamor Lemma: miamor
# Actual: Diosa Lemma: Diosa
# Actual: de Lemma: de
# Actual: mi Lemma: mi
# Actual: corazĂłn Lemma: corazĂłn
# Actual: you Lemma: you
# Actual: are Lemma: are
# Actual: incredibly Lemma: incredibly
# Actual: beautiful Lemma: beautiful
# Actual: Let Lemma: Let
# Actual: me Lemma: me
# Actual: give Lemma: give
# Actual: it Lemma: it
# Actual: to Lemma: to
# Actual: you Lemma: you
# Actual: , Lemma: ,
# Actual: while Lemma: while
# Actual: you Lemma: you
# Actual: take Lemma: take
# Actual: it Lemma: it
# Actual: willingly Lemma: willingly
# Actual: dua Lemma: dua
# Actual: lipa Lemma: lipa
# Actual: Dua Lemma: Dua
# Actual: Lipa Lemma: Lipa
# Actual: Always Lemma: Always
# Actual: so Lemma: so
# Actual: beautifulâ¤ď¸ Lemma: beautifulâ¤ď¸
# Actual: You Lemma: You
# Actual: are Lemma: are
# Actual: very Lemma: very
# Actual: pretty Lemma: pretty
# Actual: , Lemma: ,
# Actual: I Lemma: I
# Actual: love Lemma: love
# Actual: you Lemma: you
# Actual: Dua Lemma: Dua
# Actual: â¤ď¸â¤ď¸â¤ď¸ Lemma: â¤ď¸â¤ď¸â¤ď¸
# Actual: Beautiful Lemma: Beautiful
# Actual: ... Lemma: ...
# Actual: I Lemma: I
# Actual: love Lemma: love
# Actual: this Lemma: this
# Actual: outfit Lemma: outfit
# Actual: . Lemma: .

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\HOME\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
text = nltk.word_tokenize(text) 
print(nltk.pos_tag(text))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-0c1fe75ad1ef> in <module>
# ----> 1 fm = nltk.word_tokenize(text)
#       2 print(nltk.pos_tag(fm))
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\__init__.py in word_tokenize(text, language, preserve_line)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
#     131         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\__init__.py in sent_tokenize(text, language)
#     105     """
#     106     tokenizer = load("tokenizers/punkt/{0}.pickle".format(language))
# --> 107     return tokenizer.tokenize(text)
#     108
#     109
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in tokenize(self, text, realign_boundaries)
#    1270         Given a text, returns a list of the sentences in that text.
#    1271         """
# -> 1272         return list(self.sentences_from_text(text, realign_boundaries))
#    1273
#    1274     def debug_decisions(self, text):
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1324         follows the period.
#    1325         """
# -> 1326         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1327
#    1328     def _slices_from_text(self, text):
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in <listcomp>(.0)
#    1324         follows the period.
#    1325         """
# -> 1326         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1327
#    1328     def _slices_from_text(self, text):
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in span_tokenize(self, text, realign_boundaries)
#    1314         if realign_boundaries:
#    1315             slices = self._realign_boundaries(text, slices)
# -> 1316         for sl in slices:
#    1317             yield (sl.start, sl.stop)
#    1318
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in _realign_boundaries(self, text, slices)
#    1355         """
#    1356         realign = 0
# -> 1357         for sl1, sl2 in _pair_iter(slices):
#    1358             sl1 = slice(sl1.start + realign, sl1.stop)
#    1359             if not sl2:
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in _pair_iter(it)
#     312     it = iter(it)
#     313     try:
# --> 314         prev = next(it)
#     315     except StopIteration:
#     316         return
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in _slices_from_text(self, text)
#    1328     def _slices_from_text(self, text):
#    1329         last_break = 0
# -> 1330         for match in self._lang_vars.period_context_re().finditer(text):
#    1331             context = match.group() + match.group("after_tok")
#    1332             if self.text_contains_sentbreak(context):
#
# TypeError: expected string or bytes-like object
